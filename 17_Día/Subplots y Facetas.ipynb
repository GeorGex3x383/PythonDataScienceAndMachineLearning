# %% [markdown]
# # Subplots y Facetas
#
# En esta lección vamos a dar un paso más hacia adelante con Plotly, y vamos a aprender a crear **gráficos que contienen subplots**, al igual que aprendimos a hacerlo con *matplotlib* y con *seaborn*.
#
# Te vas a sorprender por lo fácil que es hacer esta proeza usando la amigable interface de plotly.
#
# Primero, vamos a necesitar importar otro recurso de plotly, además de `graph_objects`, que se llama `make_subplots`.

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# Vamos a crear una figura, pero esta vez usando `make_subplots()`, a la que le vamos a pedir que sea una parrila de **2 filas** y **dos columnas** de subplots.

# %%
fig = make_subplots(rows=2, cols=2)

# %% [markdown]
# Y como esta grilla es de 2x2, eso significa que voy a poder colocar aquí **4 gráficos**. Voy a comenzar a crearlos de a uno, y a agregarlos a mi figura, usando la función `add_trace()`.

# %%
plot1 = go.Scatter(x=[1, 2, 3],
                   y=[4, 5, 6],
                   mode='lines+markers',
                   name='Plot 1')
fig.add_trace(plot1, row=1, col=1)

# %%
plot2 = go.Bar(x=['A', 'B', 'C'],
               y=[7, 8, 9],
               name='Plot 2')
fig.add_trace(plot2, row=1, col=2)

# %%
plot3 = go.Scatter(x=[1, 2, 3],
                   y=[2, 3, 4],
                   mode='markers',
                   name='Plot 3')
fig.add_trace(plot3, row=2, col=1)

# %%
plot4 = go.Bar(x=['X', 'Y', 'Z'],
               y=[1, 3, 2],
               name='Plot 4')
fig.add_trace(plot4, row=2, col=2)

# %% [markdown]
# Y por supuesto, a esta figura, por más que sea de 4 gráficos, igualmente le pudo actualizar su **layout general**, como su título o la leyenda, por ejemplo.

# %%
fig.update_layout(title="Subplots Básicos",
                 showlegend=False)

# %% [markdown]
# Pero observa un detalle. En esta figura de 4 gráficos, cada gráfico tiene **sus propios ejes `x` e `y`**, que son **independientes entre sí**. Esta es una forma válida de mostrar datos que representan diferentes escalas o referencias de valores.
#
# Pero si se diera el caso de que necesites que todos los gráficos se ajusten a una **misma escala de ejes**, podemos configurar el `make_subplots()` para que sus gráficos compartan entre sí estos ejes.

# %%
fig2 = make_subplots(rows=2, cols=2, shared_xaxes=True, shared_yaxes=True)
fig2.add_trace(plot1, row=1, col=1)
fig2.add_trace(plot2, row=1, col=2)
fig2.add_trace(plot3, row=2, col=1)
fig2.add_trace(plot4, row=2, col=2)
fig2.update_layout(title="Subplots con ejes Compartidos",
                 showlegend=False)

# %% [markdown]
# Por último quiero mostrarte que con plotly también podemos **facetar** nuestros gráficos tal como hacíamos en **seaborn**, es decir: hacer que un mismo gráfico se divida en dos o más gráficos para separar sus datos según alguna de sus categorías. Cuando lo veas lo vas a recordar.

# %%
import plotly.express as px

# %%
df = px.data.iris()

# %%
px.scatter(df,
          x='sepal_width',
          y='sepal_length',
          color='species',
          facet_col='species',
          title='Gráfico facetado por especie')

# %% [markdown]
# Entonces en esta lección hemos aprendido que plotly también tiene la capacidad de crear gráficos compuestos de múltiples plots, y eso nos va dando una idea de que aunque parece simple, plotly también es muy poderoso. No te van a quedar dudas de esto, cuando veas todo lo que sigue.

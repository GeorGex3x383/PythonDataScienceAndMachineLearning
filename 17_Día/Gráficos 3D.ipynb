# %% [markdown]
# # Gráficos en 3D
#
# Voy a repetir una promesa que creo haber cumplido cada vez que la hice: Esta va a ser una lección especial.
#
# Y si me animo a decirlo es porque en esta lección vamos a ver cómo crear gráficos en 3 dimensiones, lo cuál es algo nuevo para el curso, porque no hemos visto este tipo de gráficos en ninguna de las librerías con las que hemos trabajado hasta ahora.
#
# El primer ejemplo que te voy a mostrar es muy similar al de cualquier gráfico de tipo **scatter** que hemos hecho hasta ahora (porque de hecho aunque tenga 3 dimensiones en vez de 2, sigue siendo un gráfico de dispersión). La principal diferencia es que en vez de usar la función `Scatter()`, vamos a usar la función `Scatter3d()`. Y por la naturaleza de los gráficos el único parámetro que tenemos que agregar por fuerza es el que representa al eje `z`.

# %%
import plotly.graph_objects as go
import numpy as np

# %%
fig = go.Figure(data=[go.Scatter3d(x=[1, 2, 3, 4, 5],
                                  y=[10, 11, 12, 13, 14],
                                  z=[5, 6, 7, 8, 9],
                                  mode='markers',
                                  marker=dict(size=10,
                                             color=[10, 20, 30, 40, 50],
                                             colorscale='Viridis',
                                             opacity=0.8))])
fig.update_layout(title='Gráfico en 3D',
                 scene=dict(xaxis_title='Eje X',
                           yaxis_title='Eje Y',
                           zaxis_title='Eje Z'))

# %% [markdown]
# Al igual que con los gráficos de mapas, no dejes de jugar con la interactividad que presentan los gráficos 3D, ya que si haces click en ellos puedes arrastrarlos para girarlos, o puedes hacer zoom con la rueda del mouse.
#
# Ahora avancemos y creemos otro gráfico 3D, pero esta vez haremos que sea un gráfico de superficie. El primer paso será crear esa superficie que va a requerir 3 ejes (`x`, `y` y `z`). Pero para hacer una superficie interesante (es decir, una superficie que no sea plana), vamos a hacer primero una malla compuesta por los valores de `x` e `y`, y luego `z` será el resultado de una serie de operaciones de **seno**, **raíz cuadrada** y **potencia**, que le darán movimiento a la malla sobre el eje de `z`.

# %%
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

# %% [markdown]
# Si no puedes imaginarte como se representarían estos números en una superficie real, no te preocupes, esa es la idea de tener gráficos en 3D. Lo que sí tienes que aprender es cómo trasladar esa información a un gráfico `Surface()` (otra función de plotly), lo cual por suerte es extremadamente sencillo.

# %%
fig = go.Figure(data=[go.Surface(z=z, x=x, y=y, colorscale='Viridis')])

# %%
fig
# Out:
# <div>                            <div id="71a10d96-c223-478c-a15a-f0d81c9d57f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71a10d96-c223-478c-a15a-f0d81c9d57f2")) {                    Plotly.newPlot(                        "71a10d96-c223-478c-a15a-f0d81c9d57f2",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"x":[[-5.0,-4.795918367346939,-4.591836734693878,-4.387755102040816,-4.183673469387755,-3.979591836734694,-3.7755102040816326,-3.571428571428571,-3.36734693877551,-3.16326
# ...

# %% [markdown]
# Y quisiera darte un último ejemplo antes de terminar esta lección, donde representaremos los mismos datos del primer gráfico, pero esta vez en un gráfico de lineas en 3D.

# %%
fig = go.Figure(data=[go.Scatter3d(x=[1, 2, 3, 4, 5],
                                  y=[10, 11, 12, 13, 14],
                                  z=[5, 6, 7, 8, 9],
                                  mode='lines',
                                  line=dict(color='blue',
                                           width=2))])
fig.update_layout(title='Gráfico de lineas en 3D',
                 scene=dict(xaxis_title='Eje X',
                           yaxis_title='Eje Y',
                           zaxis_title='Eje Z'))

# %% [markdown]
# No me cansaré de repetir que estos son solo ejemplos. Mi objetivo es que a través de aprender a implementar estos ejemplos puedas luego bucear en la basta variedad de opciones gráficas de plotly para crear gráficos en 3D, y que entonces puedas implementar los requisitos específicos de cada gráfico usando las ayudas que ya sabes usar.
#
# Dime si no he cumplido mi promes ¿Ha sido esta una lección especial?
